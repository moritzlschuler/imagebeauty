# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import glob
import shutil
from sklearn.model_selection import train_test_split

# %%
DATA_DIR = "./drive/My Drive/imagebeauty/data/GPA/"

# %%
pos_img_paths = [p for p in glob.glob(DATA_DIR + 'Pos_Resize' + '/*.jpg')]
neg_img_paths = [p for p in glob.glob(DATA_DIR + 'Neg_Resize' + '/*.jpg')]

# %%
pos_train, pos_test = train_test_split(pos_img_paths, train_size = 0.7)
neg_train, neg_test = train_test_split(neg_img_paths, train_size = 0.7)
print(pos_train[:10])
print(len(pos_train))
print(len(pos_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-962cf76c8b04> in <module>()
# ----> 1 pos_train, pos_test = train_test_split(pos_img_paths, train_size = 0.7)
#       2 neg_train, neg_test = train_test_split(neg_img_paths, train_size = 0.7)
#       3 print(pos_train[:10])
#       4 print(len(pos_train))
#       5 print(len(pos_test))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2120     n_samples = _num_samples(arrays[0])
#    2121     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2122                                               default_test_size=0.25)
#    2123
#    2124     if shuffle is False:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1803             'resulting train set will be empty. Adjust any of the '
#    1804             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1805                                                 train_size)
#    1806         )
#    1807
#
# ValueError: With n_samples=0, test_size=None and train_size=0.7, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
for i in pos_train:
  shutil.move(i, './drive/My Drive/imagebeauty/data/GPA/training/positive/')

# %%
for i in neg_train:
  shutil.move(i, './drive/My Drive/imagebeauty/data/GPA/training/negative/')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-19-c2bd2aabd654> in <module>()
#       1 for i in neg_train:
# ----> 2   shutil.move(i, './drive/My Drive/imagebeauty/data/GPA/training/negative/')
#
# /usr/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     562         real_dst = os.path.join(dst, _basename(src))
#     563         if os.path.exists(real_dst):
# --> 564             raise Error("Destination path '%s' already exists" % real_dst)
#     565     try:
#     566         os.rename(src, real_dst)
#
# Error: Destination path './drive/My Drive/imagebeauty/data/GPA/training/negative/221_00116.jpg' already exists

# %%
for i in pos_test:
  shutil.move(i, './drive/My Drive/imagebeauty/data/GPA/testing/positive/')

# %%
for i in neg_test:
  shutil.move(i, './drive/My Drive/imagebeauty/data/GPA/testing/negative/')
